# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]

# %%
plt.hist(dataset, bins=10)
plt.title('Dataset with Outliers')
# Out:
# Text(0.5, 1.0, 'Dataset with Outliers')

# %%
# Z-score method for outlier detection:

outliers = []

def detect_outliers(data):
    threshold = 3 # 3rd standard deviation
    mean = np.mean(data)
    std = np.std(data)

    for i in data:
        z_score = (i - mean) / std # calculate z-score
        if np.abs(z_score) > threshold: # if z-score is greater than threshold, it's an outlier
            outliers.append(i)
    return outliers

# %%
detected_outliers = detect_outliers(dataset)
print("Outliers detected:", detected_outliers)
# Out:
# Outliers detected: [102, 107, 108]

# %%
# IQR method for outlier detection:

'''
1. sort the data
2. calculate Q1 and Q3
3. calculate IQR = Q3 -Q1
4. calculate lower bound = (Q1 - 1.5 * IQR)
5. calculate upper bound = (Q3 + 1.5 * IQR)
6. identify outliers as values outside the bounds
'''
# Out:
# '\n1. sort the data\n2. calculate Q1 and Q3\n3. calculate IQR = Q3 -Q1\n4. calculate lower bound = (Q1 - 1.5 * IQR)\n5. calculate upper bound = (Q3 + 1.5 * IQR)\n6. identify outliers as values outside the bounds\n'

# %%
# Step 1: Sort the data:

dataset.sort()
dataset
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  17,
#  19,
#  102,
#  107,
#  108]

# %%
# Step 2: Calculate Q1 and Q3:

Q1, Q3 = np.percentile(dataset, [25, 75])
print("Q1:", Q1)
print("Q3:", Q3)
# Out:
# Q1: 12.0
# Q3: 15.0

# %%
# Step 3: Calculate IQR:

IQR = Q3 - Q1
print("IQR:", IQR)
# Out:
# IQR: 3.0

# %%
# Step 4: Calculate lower and upper bounds:

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: 7.5
# Upper Bound: 19.5

# %%
# Step 5: Identify outliers as values outside the bounds:

sns.boxplot(dataset, orient='h')
# Out:
# <Axes: >
