# %% [markdown]
# # Without Pipeline Import

# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open("C:/Users/kadit/ML-Journey/models/ohe_sex.pkl", 'rb'))
ohe_embarked = pickle.load(open("C:/Users/kadit/ML-Journey/models/ohe_embarked.pkl", 'rb'))
clf = pickle.load(open("C:/Users/kadit/ML-Journey/models/clf.pkl", 'rb'))

# %% [markdown]
# After again doing the train and split we will get the desired outcome after passing imputs of the fellow passenger whether he/she will survive or not. As this process is quiet lenghty and not efficient in industry as in order to fix something we need to fix the whole production code. Therefore, we use pipelines to automate the process. Hence, I am directly skipping to it in the next file.

# %% [markdown]
# # With Pipeline Import

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# Assumed user input for testing:

test_input2 = np.array ([2, 'male', 31.0 , 0 , 0, 10.5, 'S'], dtype = object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# c:\Users\kadit\ML-Journey\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\kadit\ML-Journey\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# passenger will not survive
