# %%
#INDEXING AND SORTING DATAFRAMES:

import pandas as pd

df = pd.read_excel(r".../datasets/world_population_excel_workbook.xlsx")

df.set_index(['Continent', 'Country'], inplace=True)

df.sort_index(inplace=True)

df
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers         44903225
#               Angola          42  AGO       Luanda         35588987
#               Benin           77  BEN   Porto-Novo         13352864
#               Botswana       144  BWA     Gaborone          2630296
#               Burkina Faso    58  BFA  Ouagadougou         22673762
# ...                          ...  ...          ...              ...
# South America Paraguay       109  PRY    AsunciÃ³n          6780744
#               Peru            44  PER         Lima         34049588
#               Suriname       170  SUR   Paramaribo           618040
#               Uruguay        133  URY   Montevideo          3422794
#               Venezuela       51  VEN      Caracas         28301696
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
df.loc["Africa"]
# Out:
#                           Rank CCA3       Capital  2022 Population  \
# Country
# Algeria                     34  DZA       Algiers         44903225
# Angola                      42  AGO        Luanda         35588987
# Benin                       77  BEN    Porto-Novo         13352864
# Botswana                   144  BWA      Gaborone          2630296
# Burkina Faso                58  BFA   Ouagadougou         22673762
# Burundi                     78  BDI     Bujumbura         12889576
# Cameroon                    53  CMR       Yaounde         27914536
# Cape Verde                 171  CPV         Praia           593149
# Central African Republic   117  CAF        Bangui          5579144
# Chad                        69  TCD     N'Djamena         17723315
# Comoros                    163  COM        Moroni           836774
# DR Congo                    15  COD      Kinshasa         99010212
# Djibouti                   160  DJI      Djibouti          1120849
# ...

# %%
df.loc["Africa", "Benin"]
# Out:
# Rank                                   77
# CCA3                                  BEN
# Capital                        Porto-Novo
# 2022 Population                  13352864
# 2020 Population                  12643123
# 2015 Population                  10932783
# 2010 Population                   9445710
# 2000 Population                   6998023
# 1990 Population                   5133419
# 1980 Population                   3833939
# 1970 Population                   3023443
# Area (kmÂ²)                        112622
# Density (per kmÂ²)               118.5635
# Growth Rate                        1.0274
# World Population Percentage          0.17
# Name: (Africa, Benin), dtype: object

# %%
df.iloc[3]
# Out:
# Rank                                144
# CCA3                                BWA
# Capital                        Gaborone
# 2022 Population                 2630296
# 2020 Population                 2546402
# 2015 Population                 2305171
# 2010 Population                 2091664
# 2000 Population                 1726985
# 1990 Population                 1341474
# 1980 Population                  938578
# 1970 Population                  592244
# Area (kmÂ²)                      582000
# Density (per kmÂ²)               4.5194
# Growth Rate                      1.0162
# World Population Percentage        0.03
# Name: (Africa, Botswana), dtype: object
